# %%
import os

# %%
path =os.getcwd() ## get current working directory
print("current working directory",path)
# Out:
# current working directory e:\Desktop\may 13\4to6monthdatascience\4to6monthdatascience\osmodul

# %%
file = os.listdir()# list all the files in the directory
print("files",file)
# Out:
# files ['os.ipynb']

# %%
os.mkdir("testing") # make directory

# %%
file = os.listdir()# list all the files in the directory
print("files",file)
# Out:
# files ['os.ipynb', 'testing']

# %%
os.rename("testing","test") ### rename the directory 

file = os.listdir()# list all the files in the directory
print("files",file)
# Out:
# files ['os.ipynb', 'test']

# %%
os.rmdir("test") ### remove directory

# %%
os.listdir()
# Out:
# ['os.ipynb']

# %%
path = "e:\Desktop\may 13\4to6monthdatascience\4to6monthdatascience\osmodul"

# %%
path = os.environ.get(path)


print("path environment variable",path)
# Out:
# path environment variable None

# %%
os.system("e:\Desktop\may 13") # to open any particular directory
# Out:
# 1

# %%
os.path.isfile(r"e:\Desktop\may 13\4to6monthdatascience\4to6monthdatascience\osmodul\os.ipynb") # to check whether the file is present or not
# Out:
# True

# %%
os.path.isdir(r"e:\Desktop\may 13\4to6monthdatascience") # to check whether the directory is present or not
# Out:
# True

# %%
path1 = r"e:\Desktop\may 13"
path2 = r"4to6monthdatascience\4to6monthdatascience"
complete_path=os.path.join(path1,path2)
os.listdir(complete_path)
# Out:
# ['.git',
#  'cli_based_application',
#  'Data visualaization',
#  'Deep learning',
#  'EDA',
#  'flask',
#  'House-prediction-project',
#  'LLM',
#  'Machine Learning',
#  'mongodb',
#  'numpy',
#  'osmodul',
#  'pandas',
#  'python',
#  'README.md',
#  'sql',
#  'sql_python']

# %%
size =os.path.getsize(r"e:\Desktop\may 13\4to6monthdatascience\4to6monthdatascience\osmodul\os.ipynb") # to get the size of the file

# %%
print("size of the file(in bytes)",size)
# Out:
# size of the file(in bytes) 5963

# %%
print("before path ",os.getcwd())
os.chdir(r"e:\Desktop\may 13\4to6monthdatascience\4to6monthdatascience")
print("after path ",os.getcwd())
# Out:
# before path  e:\Desktop\may 13\4to6monthdatascience\4to6monthdatascience\osmodul
# after path  e:\Desktop\may 13\4to6monthdatascience\4to6monthdatascience
