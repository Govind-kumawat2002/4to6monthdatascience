# %%
# !pip install langchain-community

# %%
# !!!!!!!!!!!from langchain_community.llms import Ol    l!!!!!!!!!!!!~@!#@SDS!!!ama

# %%
llm=Ollama(model = 'tinyllama')
# Out:
# C:\Users\kumaw\AppData\Local\Temp\ipykernel_12788\1869470870.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm=Ollama(model = 'tinyllama')

# %%
questions = "what is the capital of india"
response=llm.predict(questions)
print(response)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 questions = "what is the capital of india"
# ----> 2 response=llm.predict(questions)
#       3 print(response)
#
# File c:\Users\kumaw\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\_api\deprecation.py:191, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     189     warned = True
#     190     emit_warning()
# --> 191 return wrapped(*args, **kwargs)
#
# File c:\Users\kumaw\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\llms.py:1354, in BaseLLM.predict(self, text, stop, **kwargs)
#    1348 @deprecated("0.1.7", alternative="invoke", removal="1.0")
#    1349 @override
#    1350 def predict(
#    1351     self, text: str, *, stop: Optional[Sequence[str]] = None, **kwargs: Any
#    1352 ) -> str:
# ...
