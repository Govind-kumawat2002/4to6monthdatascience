# %%
# !pip install pymongo # this is used to install pymongo

# %%
from pymongo import MongoClient # this is used to connect to mongodb

# %%
url ="mongodb+srv://govind:govind2200@boss.atc0cdp.mongodb.net/"

local_url = "mongodb://localhost:27017/"

# %%
client =MongoClient(url) # this is remote database and connect to remote database

# %%
client.HOST # this is server database 0.0.0.0

# %%
client.PORT # this is server port 27017

# %%
client.list_database_names() ### this is method which is used to list the databases

# %%
database=client['ecomerce']# this is database and list_collection_names is method which is used to list the collections

# %%
database

# %%
database.list_collection_names()

# %%
collection=database['products']

# %%
print(collection.find())

# %%
for x in collection.find(): ### this is collection 
    print(x)

# %%
document={"name":"govind","email":"govind2200","password":"govind2200"}

collection.insert_one(document)

# %%
for x in collection.find():
    print(x)

# name : govind

# %%
name = input("enter your name : ")
email = input("enter your email : ")
password = input("enter your password : ")

address = input("enter your address : ")
mobile = input("enter your mobile : ")

document1={"name":name,"email":email,"password":password}
document2={"address":address,"mobile":mobile}

document=[document1,document2]


collection.insert_many(document)

# %%
document=[{"name":"name","email":"email","password":"password"}

,

{"address":"address","mobile":"mobile"}]

collection.insert_many(document)

# %%
for x in collection.find():
    print(x)
# name : govind

# %%
collection.delete_one({"name":"govind"})

# %%
for x in collection.find():
    print(x)  



frontend ===>   backend

# %%
for x in collection.find({'name': 'ritik'}):
    print(x)

# %%
client.close()

# %%
for x in collection.find():
    print(x)
